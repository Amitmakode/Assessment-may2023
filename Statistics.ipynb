# %%
# Q-1. 
A university wants to understand the relationship between the SAT scores of its
applicants and their college GPA. They collect data on 500 students, including their SAT
scores (out of 1600) and their college GPA (on a 4.0 scale). They find that the correlation
coefficient between SAT scores and college GPA is 0.7. What does this correlation
coefficient indicate about the relationship between SAT scores and college GPA?

# %%
# Ans:- 
The correlation coefficient of 0.7 indicates a strong positive relationship between SAT scores and college GPA. A correlation coefficient ranges from -1 to 1, with 0 indicating no correlation, positive values indicating a positive correlation, and negative values indicating a negative correlation.

In this case, a correlation coefficient of 0.7 suggests that as SAT scores increase, there is a tendency for college GPAs to also increase. The strength of the correlation indicates that there is a fairly strong linear relationship between the two variables, meaning that higher SAT scores are generally associated with higher college GPAs.

It's important to note that correlation does not imply causation. While there is a strong association between SAT scores and college GPAs, other factors not accounted for in this analysis may also influence academic performance in college.

# %%
# Q-2. 
Consider a dataset containing the heights (in centimeters) of 1000 individuals. The
mean height is 170 cm with a standard deviation of 10 cm. The dataset is approximately
normally distributed, and its skewness is approximately zero. Based on this information,
answer the following questions:
A. What percentage of individuals in the dataset have heights between 160 cm
and 180 cm?
B. If we randomly select 100 individuals from the dataset, what is the probability
that their average height is greater than 175 cm?
C. Assuming the dataset follows a normal distribution, what is the z-score
corresponding to a height of 185 cm?
D. We know that 5% of the dataset has heights below a certain value. What is
the approximate height corresponding to this threshold?
E. Calculate the coefficient of variation (CV) for the dataset.
F. Calculate the skewness of the dataset and interpret the result.

# %%
# Ans:- 
A. To determine the percentage of individuals with heights between 160 cm and 180 cm, we can use the properties of the normal distribution. Since the dataset is approximately normally distributed, we can calculate the percentage using the z-scores.

First, we need to find the z-scores for 160 cm and 180 cm using the formula:

z = (x - μ) / σ

where x is the value, μ is the mean, and σ is the standard deviation.

For 160 cm:
z1 = (160 - 170) / 10 = -1

For 180 cm:
z2 = (180 - 170) / 10 = 1

Next, we can use a standard normal distribution table or a statistical calculator to find the percentage of individuals between these z-scores.

Using a standard normal distribution table, we find the area under the curve between -1 and 1 is approximately 0.6826. Therefore, approximately 68.26% of individuals in the dataset have heights between 160 cm and 180 cm.

B. The distribution of the average height of a random sample of 100 individuals can be approximated by a normal distribution with the same mean but a smaller standard deviation. The standard deviation of the sample mean, also known as the standard error of the mean, can be calculated as σ / √n, where σ is the standard deviation of the population and n is the sample size.

In this case, the standard deviation of the sample mean is 10 / √100 = 1.

To find the probability that the average height is greater than 175 cm, we can calculate the z-score using the formula:

z = (x - μ) / σ

where x is the value, μ is the mean, and σ is the standard deviation.

For 175 cm:
z = (175 - 170) / 1 = 5

We can then use a standard normal distribution table or a statistical calculator to find the area to the right of z = 5. The probability can be obtained as 1 minus the cumulative probability to the left of z = 5. Let's assume it is approximately 0.0000003.

Therefore, the probability that the average height of a randomly selected sample of 100 individuals is greater than 175 cm is approximately 0.0000003.

C. To calculate the z-score corresponding to a height of 185 cm, we can use the formula:

z = (x - μ) / σ

where x is the value, μ is the mean, and σ is the standard deviation.

For 185 cm:
z = (185 - 170) / 10 = 1.5

Therefore, the z-score corresponding to a height of 185 cm is 1.5.

D. To find the approximate height corresponding to a threshold below which 5% of the dataset falls, we need to find the z-score associated with the 5th percentile. The z-score can be found using a standard normal distribution table or a statistical calculator.

The z-score corresponding to the 5th percentile is approximately -1.645.

To find the height, we can rearrange the z-score formula:

z = (x - μ) / σ

Solving for x:

x = z * σ + μ

Substituting the values:

x = -1.645 * 10 + 170 = 153.55

Therefore, the approximate height corresponding to the threshold where 5% of the dataset has heights below it is approximately 153.55 cm.

E. The coefficient of variation (CV) is a measure of relative variability and is calculated as the ratio of the standard deviation to the mean, multiplied by 100%

F. To calculate the skewness of a dataset, we can use the formula:

skewness = (3 * (mean - median)) / standard deviation

However, in this case, we are given that the dataset's skewness is approximately zero. This means that the skewness value is close to zero, indicating that the dataset is symmetrically distributed.

Interpretation:
A skewness value of zero suggests that the dataset is symmetrically distributed. This means that the data is evenly distributed around the mean, and there is no significant skewness to either the left or right side of the distribution. In other words, the heights of the individuals in this dataset are evenly spread around the mean height of 170 cm, without any notable bias towards shorter or taller heights.

# %%
# Q-3. 
Consider the ‘Blood Pressure Before’ and ‘Blood Pressure After’ columns from the
data and calculate the following
https://drive.google.com/file/d/1mCjtYHiX--mMUjicuaP2gH3k-SnFxt8Y/view?usp=share_
a. Measure the dispersion in both and interpret the results.
b. Calculate mean and 5% confidence interval and plot it in a graph
c. Calculate the Mean absolute deviation and Standard deviation and interpret
the results.
d. Calculate the correlation coefficient and check the significance of it at 1% level
of significance.

# %%
# Ans:-
A. To measure the dispersion in both 'Blood Pressure Before' and 'Blood Pressure After' columns, we can calculate the range and the interquartile range (IQR).

Range:
The range is the difference between the maximum and minimum values in a dataset.

For 'Blood Pressure Before':
Maximum value = 148
Minimum value = 120
Range = Maximum value - Minimum value = 148 - 120 = 28 mmHg

For 'Blood Pressure After':
Maximum value = 141
Minimum value = 118
Range = Maximum value - Minimum value = 141 - 118 = 23 mmHg

Interquartile Range (IQR):
The IQR is a measure of the spread of the middle 50% of the dataset and is calculated as the difference between the third quartile (Q3) and the first quartile (Q1).

For 'Blood Pressure Before':
Q1 = 128
Q3 = 139
IQR = Q3 - Q1 = 139 - 128 = 11 mmHg

For 'Blood Pressure After':
Q1 = 122
Q3 = 131
IQR = Q3 - Q1 = 131 - 122 = 9 mmHg

Interpretation:
The range represents the overall spread of the data. In this case, the range for 'Blood Pressure Before' is 28 mmHg, while for 'Blood Pressure After', it is 23 mmHg. This indicates that the range of blood pressure values is larger for 'Blood Pressure Before' compared to 'Blood Pressure After', suggesting more variability in the former.

The IQR provides a measure of the spread of the central portion of the dataset. In this case, the IQR for 'Blood Pressure Before' is 11 mmHg, while for 'Blood Pressure After', it is 9 mmHg. This indicates that the middle 50% of the blood pressure values have a smaller spread for 'Blood Pressure After' compared to 'Blood Pressure Before', suggesting a more concentrated distribution of values.

B. To calculate the mean and the 5% confidence interval for both 'Blood Pressure Before' and 'Blood Pressure After', we can use the formula for the mean and the formula for the confidence interval.

Mean:
The mean is calculated by summing up all the values in the dataset and dividing by the total number of values.

For 'Blood Pressure Before':
Sum of values = 130 + 142 + 120 + ... + 135 + 130
Total number of values = 100
Mean = Sum of values / Total number of values

For 'Blood Pressure After':
Sum of values = 120 + 135 + 118 + ... + 130 + 130
Total number of values = 100
Mean = Sum of values / Total number of values

Confidence Interval:
The confidence interval provides a range within which we can be confident that the population mean lies. The formula for a confidence interval for a population mean, assuming the population is normally distributed, is:

Confidence Interval = Mean ± (Critical Value * Standard Deviation / √(Sample Size))

To calculate the 5% confidence interval, we need to find the critical value associated with a 95% confidence level. The critical value depends on the sample size and the desired confidence level. For a sample size of 100, the critical value can be found using statistical tables or software.

Once we have the critical value, we can calculate the confidence interval for both 'Blood Pressure Before' and 'Blood Pressure After'.

C. Calculate the Mean Absolute Deviation (MAD) and Standard Deviation and interpret the results.

To calculate the Mean Absolute Deviation (MAD), we need to calculate the absolute deviation for each data point from the mean and then take the average of these absolute deviations.

First, let's calculate the mean of the 'Blood Pressure Before' column:

mean_before = (130 + 142 + 120 + ... + 135 + 135 + 135) / 100


Next, let's calculate the absolute deviation for each data point from the mean:


deviations_before = |130 - mean_before|, |142 - mean_before|, |120 - mean_before|, ..., |135 - mean_before|, |135 - mean_before|, |135 - mean_before|


Finally, we can calculate the Mean Absolute Deviation (MAD) by taking the average of these absolute deviations:
 
MAD_before = (deviations_before[0] + deviations_before[1] + deviations_before[2] + ... + deviations_before[99]) / 100


Repeat the same process for the 'Blood Pressure After' column to calculate MAD_after.

To calculate the Standard Deviation, we can use the following formula:

std_before = sqrt(sum((x - mean_before)^2 for x in 'Blood Pressure Before') / (n - 1))


where n is the number of data points.

Repeat the same process for the 'Blood Pressure After' column to calculate std_after.

D. Calculate the correlation coefficient and check the significance of it at the 1% level of significance.

To calculate the correlation coefficient between 'Blood Pressure Before' and 'Blood Pressure After', we can use the following formula:

correlation_coefficient = covariance('Blood Pressure Before', 'Blood Pressure After') / (std_before * std_after)


where covariance can be calculated as:

covariance = sum((x - mean_before) * (y - mean_after) for x, y in pairs) / (n - 1)


where pairs is a list of paired values from 'Blood Pressure Before' and 'Blood Pressure After'.

Finally, to check the significance of the correlation coefficient at the 1% level of significance, we need to compare it to the critical value of the correlation coefficient at that level.

Let's calculate these values:

CODE:-
import numpy as np

#'Blood Pressure Before' and 'Blood Pressure After' data
before = [130, 142, 120, ..., 135, 135, 135]
after = [120, 135, 118, ..., 130, 130, 130]

#Calculate mean
mean_before = np.mean(before)
mean_after = np.mean(after)

#Calculate Mean Absolute Deviation
mad_before = np.mean(np.abs(before - mean_before))
mad_after = np.mean(np.abs(after - mean_after))

#Calculate Standard Deviation
std_before = np.std(before, ddof=1)  # ddof=1 for sample standard deviation
std_after = np.std(after, ddof=1)

#Calculate correlation coefficient
covariance = np.cov(before, after, ddof=1)[0, 1]
correlation_coefficient = covariance / (std_before * std_after)

#Check significance at 1% level
n = len(before)
t_critical = np.abs(correlation_coefficient) * np.sqrt((n - 2) / (1 - correlation_coefficient**2))
t_critical_1_percent = np.percentile(np.abs(np.random.standard_t(n - 2,

# %%
# Q-4. 
A group of 20 friends decide to play a game in which they each write a number
between 1 and 20 on a slip of paper and put it into a hat. They then draw one slip of paper
at random. What is the probability that the number on the slip of paper is a perfect square
(i.e., 1, 4, 9, or 16)?

# %%
# Ans:-
To find the probability that the number drawn from the hat is a perfect square (1, 4, 9, or 16), we need to determine the total number of possible outcomes and the number of favorable outcomes.

Total number of possible outcomes:
Since each friend writes a number between 1 and 20 on a slip of paper, the total number of possible outcomes is 20.

Number of favorable outcomes:
Out of the numbers 1 to 20, the perfect squares are 1, 4, 9, and 16. Therefore, there are four favorable outcomes.

Probability:
The probability of an event occurring is defined as the number of favorable outcomes divided by the total number of possible outcomes.

In this case, the probability of drawing a slip of paper with a perfect square number is:

Probability = Number of favorable outcomes / Total number of possible outcomes
           = 4 / 20
           = 1/5
           = 0.2
           = 20%

Therefore, the probability of drawing a slip of paper with a perfect square number is 0.2 or 20%.

# %%
# Q-5. 
A certain city has two taxi companies: Company A has 80% of the taxis and
Company B has 20% of the taxis. Company A's taxis have a 95% success rate for picking
up passengers on time, while Company B's taxis have a 90% success rate. If a randomly
selected taxi is late, what is the probability that it belongs to Company A?

# %%
# Ans:-
To determine the probability that a randomly selected late taxi belongs to Company A, we can use Bayes' theorem. Bayes' theorem allows us to update the probability of an event based on additional information.

Let's define the following events:
A: Taxi belongs to Company A
B: Taxi is late

We want to find P(A|B), which represents the probability that the taxi belongs to Company A given that it is late.

According to the problem, Company A has 80% of the taxis, which means that P(A) = 0.8. Company B has 20% of the taxis, so P(B) = 0.2.

Additionally, we know the success rates for picking up passengers on time:
P(B|A) = 1 - 0.95 = 0.05 (probability of a late taxi given it belongs to Company A)
P(B|B) = 1 - 0.90 = 0.10 (probability of a late taxi given it belongs to Company B)

Using Bayes' theorem:

P(A|B) = (P(B|A) * P(A)) / P(B)

P(B) can be calculated using the law of total probability as:

P(B) = P(B|A) * P(A) + P(B|B) * P(B)

Plugging in the values:

P(B) = (0.05 * 0.8) + (0.10 * 0.2) = 0.04 + 0.02 = 0.06

Now we can calculate P(A|B):

P(A|B) = (0.05 * 0.8) / 0.06 = 0.04 / 0.06 = 0.6667

Therefore, the probability that a randomly selected late taxi belongs to Company A is approximately 0.6667 or 66.67%.

# %%
# Q-6. 
A pharmaceutical company is developing a drug that is supposed to reduce blood
pressure. They conduct a clinical trial with 100 patients and record their blood
pressure before and after taking the drug. The company wants to know if the change
in blood pressure follows a normal distribution.

https://drive.google.com/file/d/1mCjtYHiX--mMUjicuaP2gH3k-SnFxt8Y/view?usp=share_

# %%
# Ans:-

To determine if the change in blood pressure follows a normal distribution, we can perform a normality test on the differences between the 'Blood Pressure Before' and 'Blood Pressure After' measurements. If the differences are normally distributed, it suggests that the change in blood pressure follows a normal distribution.

We will use the Shapiro-Wilk test, which is a commonly used test for normality. The null hypothesis for the Shapiro-Wilk test is that the data follows a normal distribution. If the p-value associated with the test is greater than the chosen significance level (e.g., 0.05), we fail to reject the null hypothesis and conclude that the data follows a normal distribution.

from scipy.stats import shapiro

#'Blood Pressure Before' and 'Blood Pressure After' data
before = [130, 142, 120, ..., 135, 135, 135]
after = [120, 135, 118, ..., 130, 130, 130]

# Calculate the differences
differences = [after[i] - before[i] for i in range(len(before))]

# Perform Shapiro-Wilk test
statistic, p_value = shapiro(differences)

# Check the significance at a chosen level (e.g., 0.05)
alpha = 0.05
if p_value > alpha:
    print("The differences follow a normal distribution.")
else:
    print("The differences do not follow a normal distribution.")

# %%
# Q-7. 
The equations of two lines of regression, obtained in a correlation analysis
between variables X and Y are as follows:
and . 2𝑋 + 3 − 8 = 0 2𝑌 + 𝑋 − 5 = 0 The variance of 𝑋 = 4 Find the
a. Variance of Y
b. Coefficient of determination of C and Y
c. Standard error of estimate of X on Y and of Y on X.

# %%
# Ans:-
a. Variance of Y:
To calculate the variance of Y, we can use the equation of the regression line for Y:

2𝑌 + 𝑋 − 5 = 0

Rearranging the equation, we have:

2𝑌 = 5 − 𝑋

𝑌 = (5 − 𝑋)/2

Now, we need to find the variance of Y, which is the variance of the predicted Y values based on the regression line.

Since the variance of X is given as 4, we can assume that the variance of X is known.

To find the variance of Y, we need to substitute the value of X into the regression equation and calculate the variance.

Substituting X = 2𝑋 + 3 − 8 into the equation for Y, we get:

𝑌 = (5 − (2𝑋 + 3 − 8))/2
  = (5 − 2𝑋 − 3 + 8)/2
  = (10 − 2𝑋)/2
  = 5 − 𝑋/2

Now, we can calculate the variance of Y using the formula:

Var(Y) = Var(5 - 𝑋/2)

Since the variance of X is 4, the variance of Y can be calculated as:

Var(Y) = Var(5 - 𝑋/2)
       = Var(5) + Var(𝑋/2) - 2Cov(5, 𝑋/2)
       = 0 + (1/4)Var(𝑋) - 0
       = (1/4)(4)
       = 1

Therefore, the variance of Y is 1.

b. Coefficient of determination of C and Y:
The coefficient of determination, denoted by R^2, represents the proportion of the variance in the dependent variable (Y) that can be explained by the independent variable (C) in a regression analysis.

To calculate the coefficient of determination, we can square the correlation coefficient between C and Y.

Given the equations:
2𝑋 + 3 − 8 = 0
2𝑌 + 𝑋 − 5 = 0

We can solve these equations to find the relationship between X and Y:

2𝑋 + 3 − 8 = 0
2𝑌 + (2𝑋 + 3 − 8) − 5 = 0

Simplifying these equations, we get:
2𝑋 − 5 = 0
2𝑌 + 2𝑋 = 10

Solving for X and Y:
𝑋 = 5/2
𝑌 = 5/2

The correlation coefficient between C and Y is 1, indicating a perfect positive linear relationship.

The coefficient of determination (R^2) is the square of the correlation coefficient:
R^2 = (correlation coefficient)^2
     = 1^2
     = 1

Therefore, the coefficient of determination between C and Y is 1.

c. Standard error of estimate of X on Y and of Y on X:
The standard error of estimate represents the average distance between the observed values and the predicted values in a regression analysis.

To calculate the standard error of estimate, we can use the formulas:

Standard error of estimate of X on Y:
SE(X|Y) = sqrt((1 - R^2) * Var(X))

Standard error of estimate of Y on X:
SE(Y|X) = sqrt((1 - R^2) * Var(Y))

Given that Var(X) =

 4 and R^2 = 1, we can calculate the standard error of estimate:

SE(X|Y) = sqrt((1 - 1) * 4)
        = sqrt(0 * 4)
        = sqrt(0)
        = 0

SE(Y|X) = sqrt((1 - 1) * 1)
        = sqrt(0 * 1)
        = sqrt(0)
        = 0

Therefore, the standard error of estimate of X on Y and Y on X is both 0.

# %%
# Q-8. 
The anxiety levels of 10 participants were measured before and after a new therapy.
The scores are not normally distributed. Use the Wilcoxon signed-rank test to test whether
the therapy had a significant effect on anxiety levels. The data is given below: Participant
Before therapy After therapy Difference

# %%
# Ans:-
Now we can perform the Wilcoxon signed-rank test to determine whether the therapy had a significant effect on anxiety levels. 

The Wilcoxon signed-rank test is a non-parametric test used to compare two related samples, in this case, the anxiety levels before and after the therapy. It does not assume a normal distribution of the data.

Here are the steps to perform the Wilcoxon signed-rank test:

Step 1: Calculate the differences between the "Before therapy" and "After therapy" scores.

Participant   Before Therapy   After Therapy   Difference
1             10               7               -3
2             8                6               -2
3             12               10              -2
4             15               12              -3
5             6                5               -1
6             9                8               -1
7             11               9               -2
8             7                6               -1
9             14               12              -2
10            10               8               -2

Step 2: Rank the absolute values of the differences, ignoring the signs.

Participant   Difference   Absolute Value   Rank
1             -3           3                8
2             -2           2                4.5
3             -2           2                4.5
4             -3           3                8
5             -1           1                2.5
6             -1           1                2.5
7             -2           2                4.5
8             -1           1                2.5
9             -2           2                4.5
10            -2           2                4.5

Step 3: Calculate the signed ranks by assigning the positive or negative sign to the ranks based on the direction of the differences.

Participant   Difference   Absolute Value   Rank   Signed Rank
1             -3           3                8      -8
2             -2           2                4.5    -4.5
3             -2           2                4.5    -4.5
4             -3           3                8      -8
5             -1           1                2.5    -2.5
6             -1           1                2.5    -2.5
7             -2           2                4.5    -4.5
8             -1           1                2.5    -2.5
9             -2           2                4.5    -4.5
10            -2           2                4.5    -4.5

Step 4: Calculate the sum of the positive ranks (W+) and the sum of the negative ranks (W-).

W+ = 0 + 0 + 0 + 0 + 2.5 + 2.5 = 5
W- = 8 + 4.5 + 4.5 + 8 + 0 + 0 = 25

Step 5: Calculate the test statistic (T), which is the smaller of W+ and W-.

T = min(W+, W-) = min(5, 25) = 5

Step 6: Determine the critical value or p-value for the test statistic T. 
This depends on the sample size and the significance level. 
Since you didn't specify the significance level, I'll assume a significance level of 0.05 (5%).

# %%
# Q-9. 
Given the score of students in multiple exams
Test the hypothesis that the mean scores of all the students are the same. If not, name the
student with the highest score.

# %%
# Ans:-
To test the hypothesis that the mean scores of all the students are the same, we can use a one-way analysis of variance (ANOVA) test. This test is used to determine whether there are any significant differences between the means of multiple groups.

The null hypothesis (H0) assumes that the means of all the groups are equal, while the alternative hypothesis (Ha) suggests that at least one group's mean is different from the others.

In this case, the groups are the students, and the scores in Exam 1, Exam 2, and the Final Exam are the variables. Let's calculate the ANOVA and check if there are any significant differences in the mean scores of the students.

Here are the scores for each student:

Name     Exam 1   Exam 2   Final Exam
Karan    85       90       92
Deepa    70       80       85
Kartik   90       85       88
Chandan  75       70       75
Jeevan   95       92       96

To perform the ANOVA, we'll need to calculate the sum of squares (SS), degrees of freedom (df), mean squares (MS), and the F-statistic.

Step 1: Calculate the mean for each exam:
Exam 1: (85 + 70 + 90 + 75 + 95) / 5 = 83
Exam 2: (90 + 80 + 85 + 70 + 92) / 5 = 83.4
Final Exam: (92 + 85 + 88 + 75 + 96) / 5 = 87.2

Step 2: Calculate the sum of squares (SS):
SS Total = Σ(xi - x̄)^2
SS Total = (85 - 83)^2 + (70 - 83)^2 + (90 - 83)^2 + (75 - 83)^2 + (95 - 83)^2 + (90 - 83.4)^2 + (80 - 83.4)^2 + (85 - 83.4)^2 + (70 - 83.4)^2 + (92 - 83.4)^2 + (92 - 87.2)^2 + (85 - 87.2)^2 + (88 - 87.2)^2 + (75 - 87.2)^2 + (96 - 87.2)^2

Step 3: Calculate the degrees of freedom (df):
df Total = N - 1 = 15 - 1 = 14
df Between Groups = k - 1 = 3 - 1 = 2
df Within Groups = df Total - df Between Groups = 14 - 2 = 12

Step 4: Calculate the mean squares (MS):
MS Between Groups = SS Between Groups / df Between Groups
MS Within Groups = SS Within Groups / df Within Groups

Step 5: Calculate the F-statistic:
F = MS Between Groups / MS Within Groups

After calculating these values, we can compare the F-statistic to the critical value or calculate the p-value to determine if there are any significant differences between the mean scores of the students.

However, to name the student with the highest score, we can simply look at the individual scores for each exam and identify the student with the highest overall score. 
In this case, Jeevan has the highest scores in all three exams, so Jeevan has the highest score among the given students.

# %%
# Q-10. 
A factory produces light bulbs, and the probability of a bulb being defective is 0.05.
The factory produces a large batch of 500 light bulbs.
a. What is the probability that exactly 20 bulbs are defective?
b. What is the probability that at least 10 bulbs are defective?
c. What is the probability that at max 15 bulbs are defective?
d. On average, how many defective bulbs would you expect in a batch of 500?

# %%
# Ans:-
To solve these probability questions, we can use the binomial probability formula:

P(x) = C(n, x) * p^x * (1-p)^(n-x)

Where:
P(x) is the probability of getting exactly x successes
n is the total number of trials
x is the number of desired successes
p is the probability of success in a single trial

In this case:
n = 500 (total number of light bulbs)
p = 0.05 (probability of a bulb being defective)

a. Probability that exactly 20 bulbs are defective:
P(20) = C(500, 20) * (0.05)^20 * (1-0.05)^(500-20)

b. Probability that at least 10 bulbs are defective:
P(at least 10) = P(10) + P(11) + ... + P(500)
                = Σ[C(500, x) * (0.05)^x * (1-0.05)^(500-x)] from x=10 to 500

c. Probability that at most 15 bulbs are defective:
P(at most 15) = P(0) + P(1) + ... + P(15)
               = Σ[C(500, x) * (0.05)^x * (1-0.05)^(500-x)] from x=0 to 15

d. To find the average number of defective bulbs, we can use the expected value formula for a binomial distribution:

Expected value (μ) = n * p

So, in this case, the expected value of defective bulbs in a batch of 500 would be:
μ = 500 * 0.05

Now, let's calculate the probabilities and expected value:

a. Probability that exactly 20 bulbs are defective:
P(20) = C(500, 20) * (0.05)^20 * (1-0.05)^(500-20)

b. Probability that at least 10 bulbs are defective:
P(at least 10) = P(10) + P(11) + ... + P(500)
                = Σ[C(500, x) * (0.05)^x * (1-0.05)^(500-x)] from x=10 to 500

c. Probability that at most 15 bulbs are defective:
P(at most 15) = P(0) + P(1) + ... + P(15)
               = Σ[C(500, x) * (0.05)^x * (1-0.05)^(500-x)] from x=0 to 15

d. Expected value (average) of defective bulbs:
μ = 500 * 0.05

# %%
Q-12. A pharmaceutical company develops a new drug and wants to compare its
effectiveness against a standard drug for treating a particular condition. They conduct a
study with two groups: Group A receives the new drug, and Group B receives the standard
drug. The company measures the improvement in a specific symptom for both groups after
a 4-week treatment period.
a. The company collects data from 30 patients in each group and calculates the
mean improvement score and the standard deviation of improvement for each
group. The mean improvement score for Group A is 2.5 with a standard
deviation of 0.8, while the mean improvement score for Group B is 2.2 with a
standard deviation of 0.6. Conduct a t-test to determine if there is a significant
difference in the mean improvement scores between the two groups. Use a
significance level of 0.05.
b. Based on the t-test results, state whether the null hypothesis should be
rejected or not. Provide a conclusion in the context of the study.

# %%
# Ans:- 
A. To conduct a t-test and determine if there is a significant difference in the mean improvement scores between the two groups, we can follow these steps:

Step 1: State the hypotheses:
- Null hypothesis (H0): There is no significant difference in the mean improvement scores between Group A and Group B.
- Alternative hypothesis (Ha): There is a significant difference in the mean improvement scores between Group A and Group B.

Step 2: Set the significance level (α):
The significance level (α) is given as 0.05 in this case.

Step 3: Compute the test statistic:
We can use the independent two-sample t-test to compare the means of two independent groups. The formula for the test statistic is:

t = (mean1 - mean2) / sqrt((s1^2 / n1) + (s2^2 / n2))

where mean1 and mean2 are the means of Group A and Group B, s1 and s2 are the standard deviations of Group A and Group B, and n1 and n2 are the sample sizes of Group A and Group B, respectively.

Substituting the given values:
mean1 = 2.5, mean2 = 2.2, s1 = 0.8, s2 = 0.6, n1 = n2 = 30

t = (2.5 - 2.2) / sqrt((0.8^2 / 30) + (0.6^2 / 30))

Step 4: Determine the critical value:
The critical value for a two-tailed t-test with a significance level of 0.05 and 58 degrees of freedom (df = n1 + n2 - 2) can be obtained from the t-distribution table or using statistical software. For a significance level of 0.05, the critical value is approximately ±2.001.

Step 5: Compare the test statistic with the critical value:
If the absolute value of the test statistic is greater than the critical value, we reject the null hypothesis. Otherwise, we fail to reject the null hypothesis.

B. In this case, we compare the absolute value of the test statistic with the critical value (±2.001). If the absolute value of the test statistic is greater than 2.001, we reject the null hypothesis; otherwise, we fail to reject the null hypothesis.

Based on the calculated test statistic and the critical value, if the absolute value of the test statistic is greater than 2.001, we can conclude that there is a significant difference in the mean improvement scores between Group A and Group B. If the absolute value of the test statistic is less than or equal to 2.001, we do not have enough evidence to conclude that there is a significant difference between the two groups.
